# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
speedup1 = [ 0.01077/0.0064007, 0.01077/0.0079250, 0.01077/0.0038186, 0.01077/0.0314944 ]
speedup2 = [ 0.90066/0.478289, 0.90066/0.242699, 0.90066/0.211447, 0.90066/0.318594]
speedup3 = [ 7.20221/3.86927, 7.20221/1.92353, 7.20221/1.67508, 7.20221/1.96554]
speedup4 = [ 24.2687/12.9034, 24.2687/6.48015, 24.2687/5.7488, 24.2687/7.07978]
speedup5 = [ 196.048/102.582, 196.048/60.0153, 196.048/53.6763, 196.048/55.7653]
num_proc = [2, 4, 8, 16]
plt.plot(num_proc, speedup1, label='n=100')
plt.plot(num_proc, speedup2, label='n=500')
plt.plot(num_proc, speedup3, label='n=1000')
plt.plot(num_proc, speedup4, label='n=1500')
plt.plot(num_proc, speedup5, label='n=2000')


plt.xlabel('Number of Threads')
plt.ylabel('Speedup')
plt.title('Parallel Efficiency Graph(OpenMP)')
plt.legend()

# %%
speedup1 = [ 0.01077/0.075223, 0.01077/0.064856, 0.01077/0.117196, 0.01077/0.174482 ]
speedup2 = [ 0.90066/0.478289, 0.90066/0.242699, 0.90066/0.211447, 0.90066/0.318594]
speedup3 = [ 24.2687/ 12.8229 ,24.2687/6.85625, 24.2687/6.11028 , 24.2687/7.69341]
speedup4 = [ 57.9258/30.0581, 57.9258/16.5827, 57.9258/14.8203, 57.9258/17.2351]
speedup5 = [ 463.067/138.238, 463.067/133.862, 463.067/142.413, 463.067/265.232]
num_proc = [2, 4, 8, 16]
plt.plot(num_proc, speedup1, label='n=100')
plt.plot(num_proc, speedup2, label='n=500')
plt.plot(num_proc, speedup3, label='n=1500')
plt.plot(num_proc, speedup4, label='n=2000')
plt.plot(num_proc, speedup5, label='n=4000')




plt.xlabel('Number of Threads')
plt.ylabel('Speedup')
plt.title('Parallel Efficiency Graph(OpenMP)')
plt.legend()
